# %% [markdown]
# <a href="https://colab.research.google.com/github/HosseinEyvazi/HyEMST/blob/main/HyEMST_Real_world.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# CELL 1
# !pip install optuna ucimlrepo -q
print("✅ Libraries installed successfully.")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.7/404.7 kB 18.1 MB/s eta 0:00:00
# ✅ Libraries installed successfully.

# %%
# CELL 3
import os

if not os.path.exists('HyEMST_multiDataset.py'):
    print("❌ ERROR: You forgot to upload 'HyEMST_multiDataset.py'!")
else:
    print("✅ File found. Starting HyEMST pipeline...")
    print("⏳ This will take 20-30 minutes. Keep this tab open.")
    print("="*80)

    # Run the script
    # !python HyEMST_multiDataset.py
# Out:
# ✅ File found. Starting HyEMST pipeline...
# ⏳ This will take 20-30 minutes. Keep this tab open.
# ...
#
# ################################################################################
# # HYEMST CLUSTERING - MULTI-DATASET EVALUATION                                 #
# ################################################################################
#
# ...
# [VALIDATION] Checking Dataset Availability
# ...
#
# ...
# [LOADING] Iris Dataset
# ...
#   ✓ Shape: (150, 4)
#   ✓ Classes: 3
#   ✓ Standardized: Yes
#   ✓ Iris                 | Ready (Samples: 150, Features: 4, Classes: 3)
#
# ...
# [LOADING] Glass Dataset
# ...
#   ⚠ Warning: Could not load Glass dataset ("Function Finding" dataset (id=41) exists in the repository, but is not available for import. Please select a dataset from this list: https://archive.ics.uci.edu/datasets?skip=0&take=10&sort=desc&orderBy=NumHits&search=&Python=true)
#   → Using synthetic data instead
#   ✓ Shape: (214, 2)
#   ✓ Classes: 6
#   ✓ Standardized: Yes
# ...
